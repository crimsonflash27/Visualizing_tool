# %% [markdown]
# ## Objective:
#
# *Whilst working on the task of image segmentation, one aspect I was confronted with involved adding some custom edits to the model in order to reduce overall parameter count or improve performance. Random addition of extra parameters didn't help my case, and that led me to understanding the role of the convolutional layers present in the network.*
#
# *To that end, I scripted code to help me visualize the feature maps of the convolutional layers in a network. As an example, we will be going to be using the visualizer on the DeeplabV3 model. The model code is obtained from the following GitHub repository: https://github.com/VainF/DeepLabV3Plus-Pytorch*

# %%
#imports
import network
import torchvision.transforms as transform
import torch
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
##Model Loading -- model is trained on custom parameters
model = network.modeling.__dict__["deeplabv3plus_mobilenet"](num_classes=151,output_stride=8).to("cuda")
ckpt = torch.load( "deeplabv3plus",map_location="cpu")
model.load_state_dict(ckpt['state_dict'])
model.eval()
del ckpt

# %%
#labels to rgb -- for visualizing the Ground Truth
def lab_to_map(x,N=151):

  
   cmap_dict = {}
   np.random.seed(0)
   for i in range(N):
      if i != 0: 
         cmap_dict[i] = tuple(np.random.randint(256, size=3))
      
   h,w = x.shape
  
   mask = np.zeros((h,w,3),dtype=np.uint8)
   for label,rgb in cmap_dict.items():
      mask[x==label,:] = rgb
   
   return mask

# %% [markdown]
# *Since the model is trained on the ADE20k dataset, we will be using an example image from that dataset*

# %%
##Loading the Image

img = Image.open("ADE_train_00007822.jpg")
img.show()


image_transform = transform.Compose([transform.ToTensor(),
        transform.Normalize(mean=(0.48897024, 0.46548376, 0.42939524), std=(0.25883686, 0.25581116, 0.27494394))
        ])
img_tensor = image_transform(img).to("cuda")
img_tensor = img_tensor.unsqueeze(0)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=378x382>

# %%
##Visualizing the mask and Ground truth

gt = np.array(Image.open("ADE_train_00007822.png"))



output = model(img_tensor)

_,predictions = output.squeeze().max(0)
preds = predictions.squeeze().cpu().numpy()

mask_map = lab_to_map(preds,N=150)
gt_map = lab_to_map(gt,N=150)

fig,ax = plt.subplots()

print("Predicted Mask: ")
ax.imshow(img)
ax.imshow(mask_map,alpha=0.4)
fig.show()
plt.show()

print("Ground Truth")
fig,ax = plt.subplots()

ax.imshow(img)
ax.imshow(gt_map,alpha=1)
fig.show()
plt.show()
# Out:
# Predicted Mask:
# /tmp/ipykernel_46767/1901739001.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Ground Truth
# /tmp/ipykernel_46767/1901739001.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ### As an example, we will be visualizing the feature maps in the final segmentation classification layer, to understand how the maps for the top 5 classes look.
#
# **Things to keep in mind:**
#
# 1. Based on the sum of the feature map tensor, we will obtain the top 5 feature maps. This can be edited in the code based on user preference.
#
# <br>
#
# 2. There are 151 channels in the output of the final conv layer, assocciated with the 151 total classes in the dataset. In our case, we hope to see the top 5 classes predicted in the input Image

# %%
## Importing the visualizer 
from visualizer import visualizer

visualizer(model,img_tensor)
# Out:
# The model Conv layers are as follows:
# The layer name: backbone.low_level_features.0.0; The layer: Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
# The layer name: backbone.low_level_features.1.conv.0.0; The layer: Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False)
# The layer name: backbone.low_level_features.1.conv.1; The layer: Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.low_level_features.2.conv.0.0; The layer: Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.low_level_features.2.conv.1.0; The layer: Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), groups=96, bias=False)
# The layer name: backbone.low_level_features.2.conv.2; The layer: Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.low_level_features.3.conv.0.0; The layer: Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.low_level_features.3.conv.1.0; The layer: Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False)
# The layer name: backbone.low_level_features.3.conv.2; The layer: Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.4.conv.0.0; The layer: Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.4.conv.1.0; The layer: Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), groups=144, bias=False)
# The layer name: backbone.high_level_features.4.conv.2; The layer: Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.5.conv.0.0; The layer: Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.5.conv.1.0; The layer: Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False)
# The layer name: backbone.high_level_features.5.conv.2; The layer: Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.6.conv.0.0; The layer: Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.6.conv.1.0; The layer: Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False)
# The layer name: backbone.high_level_features.6.conv.2; The layer: Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.7.conv.0.0; The layer: Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.7.conv.1.0; The layer: Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False)
# The layer name: backbone.high_level_features.7.conv.2; The layer: Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.8.conv.0.0; The layer: Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.8.conv.1.0; The layer: Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2), groups=384, bias=False)
# The layer name: backbone.high_level_features.8.conv.2; The layer: Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.9.conv.0.0; The layer: Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.9.conv.1.0; The layer: Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2), groups=384, bias=False)
# The layer name: backbone.high_level_features.9.conv.2; The layer: Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.10.conv.0.0; The layer: Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.10.conv.1.0; The layer: Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2), groups=384, bias=False)
# The layer name: backbone.high_level_features.10.conv.2; The layer: Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.11.conv.0.0; The layer: Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.11.conv.1.0; The layer: Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2), groups=384, bias=False)
# The layer name: backbone.high_level_features.11.conv.2; The layer: Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.12.conv.0.0; The layer: Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.12.conv.1.0; The layer: Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2), groups=576, bias=False)
# The layer name: backbone.high_level_features.12.conv.2; The layer: Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.13.conv.0.0; The layer: Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.13.conv.1.0; The layer: Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2), groups=576, bias=False)
# The layer name: backbone.high_level_features.13.conv.2; The layer: Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.14.conv.0.0; The layer: Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.14.conv.1.0; The layer: Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), dilation=(2, 2), groups=576, bias=False)
# The layer name: backbone.high_level_features.14.conv.2; The layer: Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.15.conv.0.0; The layer: Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.15.conv.1.0; The layer: Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), dilation=(4, 4), groups=960, bias=False)
# The layer name: backbone.high_level_features.15.conv.2; The layer: Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.16.conv.0.0; The layer: Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.16.conv.1.0; The layer: Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), dilation=(4, 4), groups=960, bias=False)
# The layer name: backbone.high_level_features.16.conv.2; The layer: Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.17.conv.0.0; The layer: Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: backbone.high_level_features.17.conv.1.0; The layer: Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), dilation=(4, 4), groups=960, bias=False)
# The layer name: backbone.high_level_features.17.conv.2; The layer: Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: classifier.project.0; The layer: Conv2d(24, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: classifier.aspp.convs.0.0; The layer: Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: classifier.aspp.convs.1.0; The layer: Conv2d(320, 256, kernel_size=(3, 3), stride=(1, 1), padding=(12, 12), dilation=(12, 12), bias=False)
# The layer name: classifier.aspp.convs.2.0; The layer: Conv2d(320, 256, kernel_size=(3, 3), stride=(1, 1), padding=(24, 24), dilation=(24, 24), bias=False)
# The layer name: classifier.aspp.convs.3.0; The layer: Conv2d(320, 256, kernel_size=(3, 3), stride=(1, 1), padding=(36, 36), dilation=(36, 36), bias=False)
# The layer name: classifier.aspp.convs.4.1; The layer: Conv2d(320, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: classifier.aspp.project.0; The layer: Conv2d(1280, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
# The layer name: classifier.classifier.0; The layer: Conv2d(304, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# The layer name: classifier.classifier.3; The layer: Conv2d(256, 151, kernel_size=(1, 1), stride=(1, 1))
#
#
# Please use the above printed layers as reference for selection
# Enter name of the layer you wish to visualize: classifier.classifier.3
# Layer:  classifier.classifier.3
# Number of feature maps in the layer:  151
# Top 5 feature maps:  [14  5 10 17 30]
#
#
# Map index:  14
# Map index:  5
# Map index:  10
# Map index:  17
# Map index:  30

# %% [markdown]
# **A good illustration of how conv nets work can be seen using this example:**
#
# Let us take the feature map under map index 14. Basically, this corresponds to class number 14 in the ADE20k dataset, which is the **Earth/Ground** class. As we can see in the previously printed segmentation mask, the class is basically the patches of brown on the lower and middle part of the image. **The patches in light brown have a high value in 14th channel of the output map from the Deeplabv3plus model**
#
# <br>
#
# Another feature map that gets mentioned is the one with map index 10; this corresponds to the **Grass** class. But, since this overlaps highly with the **Ground** class, it doesn't appear in the segmentation mask. The **Sky** class, which is very clearly visible in orange in the segmentation map, doesn't make its appearance in the top 5 even though its visible in the segmentation mask -- just some food for thought!
